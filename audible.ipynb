# %%
from pandera import DataFrameSchema, Column, Check
import pandas as pd
import pandera as pa
import pandera.strategies as st
import seaborn as sns
import re

# %%
# Read in data
df = pd.read_csv('audible_uncleaned.csv')
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
#                         narrator                time releasedate language  \
# 0          Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      Narratedby:JesseBernstein              10 hrs    13-01-10  English
# ...                          ...                 ...         ...      ...
# 87484    Narratedby:ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      Narratedby:RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       Narratedby:FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     Narratedby:AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     Narratedby:FleetCooper     6 hrs and 1 min    07-03-17  English
#
#                                stars   price
# 0         5 out of 5 stars34 ratings  468.00
# 1       4.5 out of 5 stars41 ratings  820.00
# 2       4.5 out of 5 stars38 ratings  410.00
# 3       4.5 out of 5 stars12 ratings  615.00
# 4      4.5 out of 5 stars181 ratings  820.00
# ...                              ...     ...
# 87484                  Not rated yet  596.00
# 87485                  Not rated yet  820.00
# 87486                  Not rated yet  938.00
# 87487                  Not rated yet  680.00
# 87488                  Not rated yet  569.00
#
# [87489 rows x 8 columns]

# %%
# Fix time column so it's not string and integer
extracted_data = df['time'].str.extract(r'(\d+)(?: hrs?(?: and (\d+) mins?))?').fillna(0).astype(int)

# Calculate total minutes
total_minutes = (extracted_data[0] * 60) + extracted_data[1]

# Add the 'total_minutes' column to the DataFrame
df['total_minutes'] = total_minutes

# %%
# Regular expression for extracting rating (floating point number at the start)
rating_extraction_regex = r'(\d+\.\d+|\d+) out of 5'
df['rating'] = df['stars'].str.extract(rating_extraction_regex).astype(float)

# Regular expression for extracting number of ratings (integer following 'stars')
number_of_ratings_extraction_regex = r'stars(\d+) ratings'
df['number_of_ratings'] = df['stars'].str.extract(number_of_ratings_extraction_regex).astype(float)

# Optionally, fill NaN values if needed
df['number_of_ratings'] = df['number_of_ratings'].fillna(0).astype(int)

# Dropping the original 'stars' column as it's no longer needed
df.drop('stars', axis=1, inplace=True)

# %%
df['author'] = df['author'].str.replace('Writtenby:', '')

# %%
df['narrator'] = df['narrator'].str.replace('Narratedby:', '')

# %%
df['author'] = df['author'].apply(lambda x: re.sub(r"(\w)([A-Z])", r"\1 \2", x))
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#              narrator                time releasedate language   price  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English  468.00
# 1       RobbieDaymond   13 hrs and 8 mins    01-05-18  English  820.00
# 2          DanRussell    2 hrs and 3 mins    06-11-20  English  410.00
# 3      SoneelaNankani  11 hrs and 16 mins    05-10-21  English  615.00
# 4      JesseBernstein              10 hrs    13-01-10  English  820.00
# ...               ...                 ...         ...      ...     ...
# 87484    ChrisStewart   7 hrs and 34 mins    09-03-17  English  596.00
# 87485      RobertFass   10 hrs and 7 mins    21-02-17  English  820.00
# 87486       FloGibson   19 hrs and 4 mins    30-12-16  English  938.00
# 87487     AntonLesser    4 hrs and 8 mins    23-02-11  English  680.00
# 87488     FleetCooper     6 hrs and 1 min    07-03-17  English  569.00
#
#        total_minutes  rating  number_of_ratings
# 0                140     5.0                 34
# 1                788     4.5                 41
# 2                123     4.5                 38
# 3                676     4.5                 12
# 4                600     4.5                181
# ...              ...     ...                ...
# 87484            454     NaN                  0
# 87485            607     NaN                  0
# 87486           1144     NaN                  0
# 87487            248     NaN                  0
# 87488            361     NaN                  0
#
# [87489 rows x 10 columns]

# %%
df['narrator'] = df['narrator'].apply(lambda x: re.sub(r"(\w)([A-Z])", r"\1 \2", x))

# %%
df['price'] = df['price'].str.replace(',', '', regex=True)
df['price'] = df['price'].replace('Free', 0)

# %%
df['price'] = df['price'].astype('float').round(2)

# %%
df['usa_prices'] = df.price / 83.12 
df['usa_prices'] = df['usa_prices'].round(2)

# %%
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator                time releasedate language  price  \
# 0          Bill Lobely   2 hrs and 20 mins    04-08-08  English  468.0
# 1       Robbie Daymond   13 hrs and 8 mins    01-05-18  English  820.0
# 2          Dan Russell    2 hrs and 3 mins    06-11-20  English  410.0
# 3      Soneela Nankani  11 hrs and 16 mins    05-10-21  English  615.0
# 4      Jesse Bernstein              10 hrs    13-01-10  English  820.0
# ...                ...                 ...         ...      ...    ...
# 87484    Chris Stewart   7 hrs and 34 mins    09-03-17  English  596.0
# 87485      Robert Fass   10 hrs and 7 mins    21-02-17  English  820.0
# 87486       Flo Gibson   19 hrs and 4 mins    30-12-16  English  938.0
# 87487     Anton Lesser    4 hrs and 8 mins    23-02-11  English  680.0
# 87488     Fleet Cooper     6 hrs and 1 min    07-03-17  English  569.0
#
#        total_minutes  rating  number_of_ratings  usa_prices
# 0                140     5.0                 34        5.63
# 1                788     4.5                 41        9.87
# 2                123     4.5                 38        4.93
# 3                676     4.5                 12        7.40
# 4                600     4.5                181        9.87
# ...              ...     ...                ...         ...
# 87484            454     NaN                  0        7.17
# 87485            607     NaN                  0        9.87
# 87486           1144     NaN                  0       11.28
# 87487            248     NaN                  0        8.18
# 87488            361     NaN                  0        6.85
#
# [87489 rows x 11 columns]

# %%
df['rating'] = df['rating'].astype(float)

# %%
df.dtypes
# Out:
# name                  object
# author                object
# narrator              object
# time                  object
# releasedate           object
# language              object
# price                float64
# total_minutes          int32
# rating               float64
# number_of_ratings      int32
# usa_prices           float64
# dtype: object

# %%
df['releasedate'] = pd.to_datetime(df['releasedate'])
df.dtypes
# Out:
# C:\Users\komis\AppData\Local\Temp\ipykernel_26708\1699994621.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['releasedate'] = pd.to_datetime(df['releasedate'])
# name                         object
# author                       object
# narrator                     object
# time                         object
# releasedate          datetime64[ns]
# language                     object
# price                       float64
# total_minutes                 int32
# rating                      float64
# number_of_ratings             int32
# usa_prices                  float64
# dtype: object

# %%
df =df.drop('time', axis=True)

# %%
df = df[['name', 'author', 'narrator', 'total_minutes', 'language', 'releasedate', 'rating','number_of_ratings', 'price', 'usa_prices']]
df
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator  total_minutes language releasedate  rating  \
# 0          Bill Lobely            140  English  2008-04-08     5.0
# 1       Robbie Daymond            788  English  2018-01-05     4.5
# 2          Dan Russell            123  English  2020-06-11     4.5
# 3      Soneela Nankani            676  English  2021-05-10     4.5
# 4      Jesse Bernstein            600  English  2010-01-13     4.5
# ...                ...            ...      ...         ...     ...
# 87484    Chris Stewart            454  English  2017-09-03     NaN
# 87485      Robert Fass            607  English  2017-02-21     NaN
# 87486       Flo Gibson           1144  English  2016-12-30     NaN
# 87487     Anton Lesser            248  English  2011-02-23     NaN
# 87488     Fleet Cooper            361  English  2017-07-03     NaN
#
#        number_of_ratings  price  usa_prices
# 0                     34  468.0        5.63
# 1                     41  820.0        9.87
# 2                     38  410.0        4.93
# 3                     12  615.0        7.40
# 4                    181  820.0        9.87
# ...                  ...    ...         ...
# 87484                  0  596.0        7.17
# 87485                  0  820.0        9.87
# 87486                  0  938.0       11.28
# 87487                  0  680.0        8.18
# 87488                  0  569.0        6.85
#
# [87489 rows x 10 columns]

# %%
df['id'] = range(1001, 1001 + len(df))
df = df[['id', 'name', 'author', 'narrator', 'total_minutes', 'language', 'releasedate', 'rating','number_of_ratings', 'price', 'usa_prices']]

# %%
df.dtypes
# Out:
# id                            int64
# name                         object
# author                       object
# narrator                     object
# total_minutes                 int32
# language                     object
# releasedate          datetime64[ns]
# rating                      float64
# number_of_ratings             int32
# price                       float64
# usa_prices                  float64
# dtype: object

# %%
schema = DataFrameSchema({
    "id": Column(int),
    "name": Column(str),
    "author": Column(str),
    "narrator": Column(str),
    "total_minutes": Column(int, coerce=True),  
    "language": Column(str),
    "releasedate": Column(pa.DateTime),
    "rating": Column(float, Check(lambda x: (x >= 0) & (x <= 5), element_wise=True), nullable=True),
    "number_of_ratings": Column(int, coerce=True), 
    "price": Column(float),
    "usa_prices": Column(float)
})

# %%
validated_df = schema.validate(df)
validated_df
# Out:
#           id                                        name            author  \
# 0       1001                  Geronimo Stilton #11 & #12  Geronimo Stilton
# 1       1002                            The Burning Maze      Rick Riordan
# 2       1003                                The Deep End       Jeff Kinney
# 3       1004                        Daughter of the Deep      Rick Riordan
# 4       1005  The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...      ...                                         ...               ...
# 87484  88485                   Last Days of the Bus Club     Chris Stewart
# 87485  88486                                    The Alps    Stephen O'Shea
# 87486  88487                        The Innocents Abroad        Mark Twain
# 87487  88488                       A Sentimental Journey   Laurence Sterne
# 87488  88489                                      Havana    Mark Kurlansky
#
#               narrator  total_minutes language releasedate  rating  \
# 0          Bill Lobely            140  English  2008-04-08     5.0
# 1       Robbie Daymond            788  English  2018-01-05     4.5
# 2          Dan Russell            123  English  2020-06-11     4.5
# 3      Soneela Nankani            676  English  2021-05-10     4.5
# 4      Jesse Bernstein            600  English  2010-01-13     4.5
# ...                ...            ...      ...         ...     ...
# 87484    Chris Stewart            454  English  2017-09-03     NaN
# 87485      Robert Fass            607  English  2017-02-21     NaN
# 87486       Flo Gibson           1144  English  2016-12-30     NaN
# 87487     Anton Lesser            248  English  2011-02-23     NaN
# 87488     Fleet Cooper            361  English  2017-07-03     NaN
#
#        number_of_ratings  price  usa_prices
# 0                     34  468.0        5.63
# 1                     41  820.0        9.87
# 2                     38  410.0        4.93
# 3                     12  615.0        7.40
# 4                    181  820.0        9.87
# ...                  ...    ...         ...
# 87484                  0  596.0        7.17
# 87485                  0  820.0        9.87
# 87486                  0  938.0       11.28
# 87487                  0  680.0        8.18
# 87488                  0  569.0        6.85
#
# [87489 rows x 11 columns]

# %%
main_df = validated_df[['id', 'name', 'author', 'narrator', 'total_minutes', 'language', 'releasedate']]
rating_df = validated_df[['id', 'rating', 'number_of_ratings']]
price_df = validated_df[['id', 'usa_prices']]

# %%
main_df.to_csv('main.csv')

# %%
rating_df.to_csv('rating.csv')

# %%
price_df.to_csv('price.csv')

# %%
price_df
# Out:
#           id  usa_prices
# 0       1001        5.63
# 1       1002        9.87
# 2       1003        4.93
# 3       1004        7.40
# 4       1005        9.87
# ...      ...         ...
# 87484  88485        7.17
# 87485  88486        9.87
# 87486  88487       11.28
# 87487  88488        8.18
# 87488  88489        6.85
#
# [87489 rows x 2 columns]

# %%
sns.histplot(main_df.total_minutes, bins = 50)
# Out:
# <Axes: xlabel='total_minutes', ylabel='Count'>

# %%
sns.histplot(main_df.releasedate, bins = 50)
# Out:
# <Axes: xlabel='releasedate', ylabel='Count'>

# %%
sns.histplot(rating_df.rating)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
sns.histplot(price_df.usa_prices, bins = 50)
# Out:
# <Axes: xlabel='usa_prices', ylabel='Count'>
