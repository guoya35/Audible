# %%
import pandas as pd

# %%
path1 = "/Users/guoyalong/Desktop/homework/Dog-Adoption/Data/allDogDescriptions.csv"
path2 = "/Users/guoyalong/Desktop/homework/Dog-Adoption/Data/dogTravel.csv"

# %%
Dog_descrip = pd.read_csv(path1)
Dog_descrip
# Out:
#        index        id org_id  \
# 0          0  46042150  NV163
# 1          1  46042002  NV163
# 2          2  46040898   NV99
# 3          3  46039877  NV202
# 4          4  46039306  NV184
# ...      ...       ...    ...
# 58175  58175  44605893   WY20
# 58176  58176  44457061   WY24
# 58177  58177  42865848   WY20
# 58178  58178  42734734   WY24
# 58179  58179  42663515   WY24
#
#                                                      url type.x species  \
# 0      https://www.petfinder.com/dog/harley-46042150/...    Dog     Dog
# 1      https://www.petfinder.com/dog/biggie-46042002/...    Dog     Dog
# 2      https://www.petfinder.com/dog/ziggy-46040898/n...    Dog     Dog
# 3      https://www.petfinder.com/dog/gypsy-46039877/n...    Dog     Dog
# 4      https://www.petfinder.com/dog/theo-46039306/nv...    Dog     Dog
# ...                                                  ...    ...     ...
# 58175  https://www.petfinder.com/dog/tren-44605893/wy...    Dog     Dog
# ...

# %%
Dog_descrip.dtypes
# Out:
# index                int64
# id                   int64
# org_id              object
# url                 object
# type.x              object
# species             object
# breed_primary       object
# breed_secondary     object
# breed_mixed           bool
# breed_unknown         bool
# color_primary       object
# color_secondary     object
# color_tertiary      object
# age                 object
# sex                 object
# size                object
# coat                object
# fixed                 bool
# house_trained         bool
# declawed           float64
# special_needs         bool
# shots_current         bool
# env_children        object
# env_dogs            object
# env_cats            object
# name                object
# status              object
# posted              object
# contact_city        object
# contact_state       object
# contact_zip         object
# contact_country     object
# stateQ              object
# accessed            object
# ...

# %%
Dog_descrip.columns
# Out:
# Index(['index', 'id', 'org_id', 'url', 'type.x', 'species', 'breed_primary',
#        'breed_secondary', 'breed_mixed', 'breed_unknown', 'color_primary',
#        'color_secondary', 'color_tertiary', 'age', 'sex', 'size', 'coat',
#        'fixed', 'house_trained', 'declawed', 'special_needs', 'shots_current',
#        'env_children', 'env_dogs', 'env_cats', 'name', 'status', 'posted',
#        'contact_city', 'contact_state', 'contact_zip', 'contact_country',
#        'stateQ', 'accessed', 'type.y', 'description'],
#       dtype='object')

# %%
Dog_descrip_df = Dog_descrip.drop(['org_id', 'index', 'url', 'type.x', 'species', 'breed_secondary', 'breed_unknown', 'color_primary', 'color_secondary', 'color_tertiary', 'coat', 'fixed', 'declawed', 'status', 'stateQ', 'accessed', 'type.y', 'posted', 'contact_zip' ], axis=1)
Dog_descrip_df
# Out:
#              id                   breed_primary  breed_mixed     age     sex  \
# 0      46042150  American Staffordshire Terrier         True  Senior    Male
# 1      46042002                Pit Bull Terrier         True   Adult    Male
# 2      46040898                        Shepherd        False   Adult    Male
# 3      46039877             German Shepherd Dog        False    Baby  Female
# 4      46039306                       Dachshund        False   Young    Male
# ...         ...                             ...          ...     ...     ...
# 58175  44605893                   Border Collie        False   Adult    Male
# 58176  44457061             Australian Shepherd         True   Young  Female
# 58177  42865848                   Border Collie        False   Adult  Female
# 58178  42734734                           Boxer         True  Senior    Male
# 58179  42663515              Labrador Retriever         True   Adult    Male
#
# ...

# %%
Dog_descrip_df.dropna(subset=['env_children', 'env_dogs', 'env_cats'], inplace=True)
Dog_descrip_df
# Out:
#              id        breed_primary  breed_mixed     age     sex    size  \
# 4      46039306            Dachshund        False   Young    Male   Small
# 5      46039304                Boxer         True    Baby    Male  Medium
# 6      46039303    Italian Greyhound         True    Baby  Female   Small
# 7      46039302           Cattle Dog         True    Baby    Male  Medium
# 8      46039301           Cattle Dog         True    Baby  Female  Medium
# ...         ...                  ...          ...     ...     ...     ...
# 58172  44658860     Pit Bull Terrier         True    Baby    Male  Medium
# 58173  44629286   Labrador Retriever         True   Adult  Female  Medium
# 58176  44457061  Australian Shepherd         True   Young  Female  Medium
# 58178  42734734                Boxer         True  Senior    Male   Large
# 58179  42663515   Labrador Retriever         True   Adult    Male   Large
#
#        house_trained  special_needs  shots_current env_children env_dogs  \
# ...

# %%
Dog_travel= pd.read_csv(path2)
Dog_travel
# Out:
#       index        id    contact_city contact_state  \
# 0         0  44520267           Anoka            MN
# 1         1  44698509       Groveland            FL
# 2         2  45983838       Adamstown            MD
# 3         3  44475904     Saint Cloud            MN
# 4         4  43877389          Pueblo            CO
# ...     ...       ...             ...           ...
# 6189   6189  40492179        Fairmont            WV
# 6190   6190  45799729  Eagle Mountain            UT
# 6191   6191  34276515          Newnan            GA
# 6192   6192  44519341          Dayton            OH
# 6193   6193  36659999        New York            NY
#
#                                             description        found  \
# 0     Boris is a handsome mini schnauzer who made hi...     Arkansas
# 1     Duke is an almost 2 year old Potcake from Abac...       Abacos
# 2     Zac Woof-ron is a heartthrob movie star lookin...         Adam
# ...

# %%
Dog_travel.dtypes
# Out:
# index             int64
# id                int64
# contact_city     object
# contact_state    object
# description      object
# found            object
# manual           object
# remove           object
# still_there      object
# dtype: object

# %%
Dog_travel.columns
# Out:
# Index(['index', 'id', 'contact_city', 'contact_state', 'description', 'found',
#        'manual', 'remove', 'still_there'],
#       dtype='object')

# %%
Dog_travel_df = Dog_travel.drop([ 'index', 'found', 'manual', 'remove'], axis=1)
Dog_travel_df
# Out:
#             id    contact_city contact_state  \
# 0     44520267           Anoka            MN
# 1     44698509       Groveland            FL
# 2     45983838       Adamstown            MD
# 3     44475904     Saint Cloud            MN
# 4     43877389          Pueblo            CO
# ...        ...             ...           ...
# 6189  40492179        Fairmont            WV
# 6190  45799729  Eagle Mountain            UT
# 6191  34276515          Newnan            GA
# 6192  44519341          Dayton            OH
# 6193  36659999        New York            NY
#
#                                             description still_there
# 0     Boris is a handsome mini schnauzer who made hi...         NaN
# 1     Duke is an almost 2 year old Potcake from Abac...         NaN
# 2     Zac Woof-ron is a heartthrob movie star lookin...         NaN
# 3     ~~Came in to the shelter as a transfer from an...         NaN
# 4     Palang is such a sweetheart. She loves her peo...         NaN
# ...

# %%
Dog_travel_df.dropna(subset=['still_there'], inplace=True)
Dog_travel_df
# Out:
#             id contact_city contact_state  \
# 319   45901219  Brattleboro            VT
# 320   44906501  Brattleboro            VT
# 321   44906474  Brattleboro            VT
# 322   44906301       Nanuet            NY
# 323   42857230  Brattleboro            VT
# ...        ...          ...           ...
# 6182  45188051     Fairmont            WV
# 6183  45017651     Fairmont            WV
# 6184  44659739     Fairmont            WV
# 6185  44289536     Fairmont            WV
# 6187  42117845     Fairmont            WV
#
#                                             description still_there
# 319   Adoption Fee: $400\n Transport Fee: $160\n\nSh...        True
# 320   Adoption Fee: $250\n Transport Fee: $160\n\n ....        True
# 321   Adoption Fee: $350\n Transport Fee: $160\n\n ....        True
# 322   Adoption Fee: $350\n Transport Fee: $160\n\n ....        True
# 323   Athena found herself at a neighbors house with...        True
# ...
